# %%
import pandas as pd
import matplotlib.pyplot as plt
from bigram_trial import accuracy
import re

biased = pd.DataFrame.from_csv('bigram_results/biased_trial.csv')
unbiased = pd.DataFrame.from_csv('bigram_results/unbiased_trial.csv')
sent = pd.DataFrame.from_csv('bigram_results/sent_trial.csv')
length = pd.DataFrame.from_csv('bigram_results/length_trial.csv')

def tweakAccuracy(data):
    data.index.name = 'Language'
    data.index = data.index.map(lambda x: re.match("([a-zA-Z]+)(\w+)?-\w+", x)[1])
    return data

def tweakDist(data):
    data.columns = data.columns.map(lambda x: re.match("([a-zA-Z]+)(\w+)?-\w+", x)[1] if re.match("([a-zA-Z]+)(\w+)?-\w+", x) else x)
    return data

def createChart(data, fname, kind='bar', title=None):
    data.plot(kind=kind)
    if title is not None:
        plt.title(title)
    plt.savefig(fname)
    return plt.show()

# %% [markdown]
# # Biased Accuracy

# %%
createChart(tweakAccuracy(accuracy(biased)), "bigram_results/biased_accuracy.png", title="Accuracy - Biased Trial")

# %% [markdown]
# # Unbiased Accuracy

# %%
createChart(tweakAccuracy(accuracy(unbiased)), "bigram_results/unbiased_accuracy.png", title="Accuracy - Unbiased Trial")

# %% [markdown]
# # Sentence Accuracy

# %%
createChart(tweakAccuracy(accuracy(sent)), "bigram_results/sent_accuracy.png", title="Accuracy - Sentence Trial")

# %% [markdown]
# # English - Biased Prediction Distributions

# %%
english = biased[biased['Expected'] == 'English-Latin1']
createChart(tweakDist(english), "bigram_results/biased_dist.png", kind="box", title="Biased Prediction Distribution for English")

# %% [markdown]
# # English - Unbiased Prediction Distributions

# %%
english = unbiased[unbiased['Expected'] == 'English-Latin1']
createChart(tweakDist(english), "bigram_results/unbiased_dist.png", kind="box", title="Unbiased Prediction Distribution for English")

# %% [markdown]
# # English - Sentence Prediction Distributions

# %%
english = sent[sent['Expected'] == 'English-Latin1']
createChart(tweakDist(english), "bigram_results/sent_dist.png", kind="box", title="Sentence Prediction Distribution for English")

# %% [markdown]
# # English - Accuracy by Length

# %%
english = length[length['Language'] == 'English-Latin1']
length_acc = pd.Series(index=english['Length'].get_values(), data=english['Accuracy'].get_values()).sort_index()

# length_acc

createChart(length_acc, "bigram_results/english_length_accuracy.png", kind="bar", title="Accuracy by Length for English")

# %% [markdown]
# # Spanish - Accuracy by Length

# %%
spanish = length[length['Language'] == 'Spanish-Latin1']
length_acc = pd.Series(index=spanish['Length'].get_values(), data=spanish['Accuracy'].get_values()).sort_index()

# length_acc

createChart(length_acc, "bigram_results/spanish_length_accuracy.png", kind="bar", title="Accuracy by Length for Spanish")

# %% [markdown]
# # French - Accuracy by Length

# %%
french = length[length['Language'] == 'French_Francais-Latin1']
length_acc = pd.Series(index=french['Length'].get_values(), data=french['Accuracy'].get_values()).sort_index()

# length_acc

createChart(length_acc, "bigram_results/french_length_accuracy.png", kind="bar", title="Accuracy by Length for French")

# %% [markdown]
# # Italian - Accuracy by Length

# %%
italian = length[length['Language'] == 'Italian-Latin1']
length_acc = pd.Series(index=italian['Length'].get_values(), data=italian['Accuracy'].get_values()).sort_index()

# length_acc

createChart(length_acc, "bigram_results/italian_length_accuracy.png", kind="bar", title="Accuracy by Length for Italian")

# %% [markdown]
# # German - Accuracy by Length

# %%
german = length[length['Language'] == 'German_Deutsch-Latin1']
length_acc = pd.Series(index=german['Length'].get_values(), data=german['Accuracy'].get_values()).sort_index()

# length_acc

createChart(length_acc, "bigram_results/german_length_accuracy.png", kind="bar", title="Accuracy by Length for German")
